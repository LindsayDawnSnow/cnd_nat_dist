# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns

# %%
# Bring in .csv created to isolate biologically related natural disasters
df = pd.read_csv("bio_nat_dist.csv")
df.head(5)
# Out:
#   event_category event_group event_subgroup   event_type  \
# 0       Disaster     Natural     Biological     Epidemic
# 1       Disaster     Natural     Biological     Epidemic
# 2       Disaster     Natural     Biological     Epidemic
# 3       Disaster     Natural     Biological     Epidemic
# 4       Disaster     Natural     Biological  Infestation
#
#                                          place       event_start_date  \
# 0                                Across Canada   1/1/1918 12:00:00 AM
# 1       Prince Edward Island and New Brunswick   1/1/1993 12:00:00 AM
# 2                              Bay of Fundy NB   1/1/1997 12:00:00 AM
# 3                Wood Buffalo National Park AB   1/1/1998 12:00:00 AM
# 4  Little Saskatchewan First Nation Reserve MB  10/1/1999 12:00:00 AM
#
#                                             comments  fatalities  \
# 0  Across Canada, 1918-1925. More than 50,000 dea...     50000.0
# 1  PVYN Potato Virus, Prince Edward Island and Ne...         0.0
# ...

# %%
# New list of biologiacl events comments for easy readibility
# Convert the "comments" column to a list and print each comment with enumeration for easy reference
bio_comments_list = df['comments'].tolist()
for i, comment in enumerate(bio_comments_list):
    print(comment)
    print(f"Index {i}:")
    print()
# Out:
# Across Canada, 1918-1925. More than 50,000 dead, two million affected; as part of a world-wide outbreak, Spanish Influenza hit Canadians hard, affecting more than one quarter of the population. The Canadian Red Cross assisted 230 communities in 1918.
# Index 0:
#
# PVYN Potato Virus, Prince Edward Island and New Brunswick, 1993. Potato crops were affected.
# Index 1:
#
# Bay of Fundy NB, 1997. ISA is caused by the Infectious Salmon Anemia Virus (ISAV), which is much like an influenza virus in salmon. It causes anemia and respiratory problems in Atlantic salmon, but does not harm humans because the virus stops producing at 25°C. Thousands of infected salmon have been removed from salmon farms in New Brunswick, especially in the Bay of Fundy Area.
# Index 2:
#
# ...
